# %% [raw]
# Q1. Explain why we have to use the Exception class while creating a Custom Exception. Note: Here Exception class refers to the base class for all the exceptions.

# %% [raw]
# >>>Exception class provides a set of common functionalities and behaviors that are useful for handling and managing exceptions in a program. By using the Exception class as the base class for our custom exception, we inherit all of these useful functionalities automatically. It's like starting with a solid foundation and building upon it.
#
# >>>Using the Exception class as the base for our custom exception allows us to leverage the built-in functionalities and behaviors provided by the Exception class. It helps us create more effective and standardized error handling in our code, making it easier to understand and debug problems when they occur.

# %% [raw]
# Q2. Write a python program to print Python Exception Hierarchy.

# %%
def print_exception_hierarchy(exception_class, indent=''):
    print(f'{indent}{exception_class.__name__}')
    for subclass in exception_class.__subclasses__():
        print_exception_hierarchy(subclass, indent + '  ')

print_exception_hierarchy(BaseException)
# Out:
# BaseException
#   Exception
#     TypeError
#       FloatOperation
#       MultipartConversionError
#     StopAsyncIteration
#     StopIteration
#     ImportError
#       ModuleNotFoundError
#       ZipImportError
#     OSError
#       ConnectionError
#         BrokenPipeError
#         ConnectionAbortedError
#         ConnectionRefusedError
#         ConnectionResetError
#           RemoteDisconnected
#       BlockingIOError
#       ChildProcessError
#       FileExistsError
#       FileNotFoundError
#       IsADirectoryError
#       NotADirectoryError
#       InterruptedError
#         InterruptedSystemCall
#       PermissionError
#       ProcessLookupError
#       TimeoutError
#       UnsupportedOperation
#       itimer_error
#       herror
#       gaierror
#       SSLError
#         SSLCertVerificationError
#         SSLZeroReturnError
#         SSLWantWriteError
#         SSLWantReadError
#         SSLSyscallError
#         SSLEOFError
#       Error
#         SameFileError
# ...

# %% [raw]
# Q3. What errors are defined in the ArithmeticError class? Explain any two with an example.

# %% [raw]
# >>>The ArithmeticError class is a base class for exceptions that occur during arithmetic operations in Python. It provides a common base for arithmetic-related errors. Some errors defined in the ArithmeticError class are:

# %% [raw]
# >>ZeroDivisionError: This error occurs when you try to divide a number by zero. It indicates an invalid operation because dividing any number by zero is mathematically undefined. Here's an example:

# %%
try:
    result = 10 / 0
except ZeroDivisionError:
    print("Error: Division by zero!")
# Out:
# Error: Division by zero!

# %% [raw]
# >>OverflowError: This error occurs when the result of an arithmetic operation is too large to be represented within the available memory space. It happens when the value exceeds the maximum limit that can be stored. Here's an example:

# %%
try:
    result = 10 ** 10000  # 10 raised to the power of 10,000
except OverflowError:
    print("Error: Result is too large to calculate!")

# %% [raw]
# Q4. Why LookupError class is used? Explain with an example KeyError and IndexError.

# %% [raw]
# >>>The LookupError class is a base class for exceptions that occur when a lookup or indexing operation fails. It provides a common base for lookup-related errors. Two examples of exceptions derived from LookupError are KeyError and IndexError.

# %% [raw]
# >>KeyError: This exception occurs when you try to access a dictionary using a key that doesn't exist in the dictionary. Here's an example:

# %%
my_dict = {'apple': 'red', 'banana': 'yellow', 'orange': 'orange'}

try:
    print(my_dict['grape'])
except KeyError:
    print("Error: Key does not exist in the dictionary!")
# Out:
# Error: Key does not exist in the dictionary!

# %% [raw]
# >>IndexError: This exception occurs when you try to access a sequence (such as a list or a string) using an index that is out of range. Here's an example:

# %%
my_list = [1, 2, 3]

try:
    print(my_list[3])
except IndexError:
    print("Error: Index is out of range!")
# Out:
# Error: Index is out of range!

# %% [raw]
# Q5. Explain ImportError. What is ModuleNotFoundError?

# %% [raw]
# >>>ImportError is an exception class in Python that is raised when an import statement fails to import a module or a name. It is a base class for various import-related exceptions.
#
# >>ImportError can occur due to several reasons, such as:
#
# >The module you are trying to import does not exist.
# >The module exists, but there is an error in the module's code.
# >The module exists, but it cannot be found in the Python's search path.
# >The module has a dependency on another module that is missing or cannot be imported.

# %%
try:
    import my_module
except ImportError:
    print("Error: Failed to import the module!")
# Out:
# Error: Failed to import the module!
